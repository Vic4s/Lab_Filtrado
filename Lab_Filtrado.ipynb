# %%
import pandas as pd

# %%
df_merge = pd.read_csv("datos/Netflix_Merge.csv", index_col=0)
df_merge.sample(3)
# Out:
#             type                      Title            director  \
# show_id
# s5171    TV Show                 The Method                 NaN
# s4041      Movie  That Thing Called Tadhana  Antoinette Jadaone
# s5776      Movie      Pac's Scary Halloween                 NaN
#
#                                                       cast      country  \
# show_id
# s5171    Konstantin Khabenskiy, Paulina Andreeva, Alexa...       Russia
# s4041                    Angelica Panganiban, JM de Guzman  Philippines
# s5776    Erin Mathews, Sam Vincent, Andrea Libman, Ashl...          NaN
#
#                 date_added  release_year rating duration  \
# show_id
# s5171    November 15, 2017          2015  TV-MA      NaN
# s4041        March 7, 2019          2015  TV-MA      NaN
# s5776      October 1, 2016          2016  TV-Y7   44 min
#
#                                                  listed_in  \
# show_id
# s5171    Crime TV Shows, International TV Shows, TV Dramas
# ...
